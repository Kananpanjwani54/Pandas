# %%
import pandas as pd

# %%
df=pd.read_csv("data2.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df["Actor"]
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df["Actor"][3]
# Out:
# 'Ranbir Kapoor'

# %%
df[["Actor","IMDb"]] #copy , original is intact
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df.loc[1]# 1st row(label based){Loc me alawys number hoga }
# Out:
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
#Suppose row no 10 col no genre chahiye 
df.loc[8,"IMDb"]
# Out:
# 7.0

# %%
#in iloc i is used means only indices values are used.means integers 
df.iloc[8 , 5]
# Out:
# 7.0

# %%
df.loc[0:2,["Actor","IMDb","Film"]]#jis order me ham denge wahi order me milenge
# Out:
#             Actor  IMDb             Film
# 0  Shah Rukh Khan   7.2          Pathaan
# 1     Salman Khan   6.0  Tiger Zinda Hai
# 2      Aamir Khan   8.4           Dangal

# %%
df.iloc[0:2,0:2] #last index exclusive need to remember
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %%
df.at[0,"Actor"] #at  function optimsed for getting only 1 value
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0,0]
# Out:
# 'Shah Rukh Khan'

# %%
df[(df['IMDb']>6)] #Condition apply data filtering
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
#we can use or operator and & opertor  for filtering'
d1=df[(df["Genre"]=="Action") & (df['Year']>2017)]
d1
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 11                   342   8.2

# %%
d2=df[(df["Genre"]=="Action") | (df['Year']>2018)] #Bitwise filtering
d2
# Out:
#              Actor                      Film  Year          Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023         Action
# 1      Salman Khan           Tiger Zinda Hai  2017         Action
# 3    Ranbir Kapoor                Brahmastra  2022        Fantasy
# 7   Hrithik Roshan                       War  2019         Action
# 8     Akshay Kumar                Good Newwz  2019         Comedy
# 9    Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 3                    431   5.6
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 11                   342   8.2

# %%
#Query function is sql inspire function 
df7=df.query("IMDb>6.5 and Genre== 'Action'")
df7
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 11                   342   8.2

# %% [markdown]
# ### Loc returns a copy not change actual data set, if needed view and copy use function for copy()
