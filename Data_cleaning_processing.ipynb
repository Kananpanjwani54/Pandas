# %%
import pandas as pd

# %%
df=pd.read_csv("data_cleaning_sample.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
#findng null values
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
#finding the sum of null value in a row
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
#removing missing data from rows
df.dropna()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
#drop columns missing data( if 1 Nan present col will be removed)
df.dropna(axis=1)
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %%
#fill the missing data
df.fillna(9) #manuallly data given
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   9.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   9.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5        9  28.0        Delhi      F     eve@domain.com           9
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   9.0        Delhi      M    charlie@example  20-07-2021

# %%
df["Age"].fillna(df["Age"].mean())  # Replace with mean
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %%
df["Age"].fillna(df["Age"].ffill())
# Out:
# 0    25.0
# 1    25.0
# 2    30.0
# 3    30.0
# 4    22.0
# 5    28.0
# 6    25.0
# 7    25.0
# 8    25.0
# Name: Age, dtype: float64

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %%
df["Age"].fillna(df["Age"].bfill())
# Out:
# 0    25.0
# 1    30.0
# 2    30.0
# 3    22.0
# 4    22.0
# 5    28.0
# 6    25.0
# 7    25.0
# 8     NaN
# Name: Age, dtype: float64

# %%
df2=df.ffill()
df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  25.0        Delhi      M    charlie@example  20-07-2021

# %%
df.bfill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
#duplicate detection and removing duplicates
df.duplicated() ##dusra duplicated value true hoga
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df1=df.drop_duplicates()
df1
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
# based on specific columns 
# agar dono column same hua inmultiple row  then wo copied hai!

df.duplicated(subset=["Name","Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
#string operations on Pandas
print(df["Name"].str.lower())
print(df["City"].str.upper())
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object
# 0       NEW YORK
# 1          DELHI
# 2    LOS ANGELES
# 3          DELHI
# 4         MUMBAI
# 5          DELHI
# 6       NEW YORK
# 7       NEW YORK
# 8          DELHI
# Name: City, dtype: object

# %%
df.fillna(True)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  True        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  True        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5  Unknown  28.0        Delhi      F     eve@domain.com        True
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  True        Delhi      M    charlie@example  20-07-2021

# %%
df["City"].str.contains("delhi",case=False)
# Checks if 'delhi' is in the city name, case-insensitive.
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: City, dtype: bool

# %%
import pandas as pd

data = {
    "City": ["  Delhi", "mumbai  ", "  BANGALORE  "]
}

df = pd.DataFrame(data)

df["City"] = df["City"].str.strip().str.upper()
print(df)
# Out:
#         City
# 0      DELHI
# 1     MUMBAI
# 2  BANGALORE

# %% [markdown]
# # What this does:
# df["City"]
# → Selects the "City" column (assumed to be strings).
#
# .str.strip()
# → Removes leading and trailing whitespace from each string.
#
# .str.upper()
# → Converts each string to uppercase.

# %%
#Type Conversion 
df2["Age"]=df2["Age"].astype(int)
df2.dtypes
# Out:
# Name         object
# Age           int32
# City         object
# Gender       object
# Email        object
# Join Date    object
# dtype: object

# %%
df2["Join Date"] = pd.to_datetime(df2["Join Date"],dayfirst=True)
df2.dtypes #converted type of joining date to date time
# Out:
# Name                 object
# Age                   int32
# City                 object
# Gender               object
# Email                object
# Join Date    datetime64[ns]
# dtype: object

# %%
#changing type to category
df["City"] = df["City"].astype("category")
df2=df.dtypes
print(df2)
d=df["Age"] = df["Age"].astype("float64")
d.dtypes
# Out:
# Name           object
# Age           float64
# City         category
# Gender         object
# Email          object
# Join Date      object
# dtype: object
# dtype('float64')

# %%
#Applying Functions
# .apply() → Apply any function to rows or columns
df3=df["Age Group"] = df["Age"].apply(lambda x: "Adult" if x >= 23 else "Minor")
df3
# Out:
# 0    Adult
# 1    Minor
# 2    Adult
# 3    Minor
# 4    Minor
# 5    Adult
# 6    Adult
# 7    Adult
# 8    Minor
# Name: Age, dtype: object

# %%
gender_map = {"M": "Male", "F": "Female"}
df1["Gender"] = df1["Gender"].map(gender_map)
# Out:
# C:\Users\kanan\AppData\Local\Temp\ipykernel_13052\3749966176.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Gender"] = df1["Gender"].map(gender_map)

# %%
df1
# Out:
#       Name   Age         City  Gender              Email   Join Date
# 0    Alice  25.0     New York  Female  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi    Male    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles    Male    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai    Male  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi  Female     eve@domain.com         NaN

# %%
df["City"].replace({"Del": "Delhi", "Mum": "Mumbai"})
# Out:
# 0       New York
# 1          Delhi
# 2    Los Angeles
# 3          Delhi
# 4         Mumbai
# 5          Delhi
# 6       New York
# 7       New York
# 8          Delhi
# Name: City, dtype: category
# Categories (4, object): ['Delhi', 'Los Angeles', 'Mumbai', 'New York']
