# %%
import pandas as pd

# %%
#During Select the series value may change means after 4 it can be 8 .
df =pd.read_csv("data2.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df.sort_values("IMDb")#default is ascending
# Out:
#                  Actor                      Film  Year            Genre  \
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#for doing descending 
df.sort_values("BoxOffice(INR Crore)",ascending=False)
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 7       Hrithik Roshan                       War  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#Using Multiple Columns
df2=df.sort_values(["Year","BoxOffice(INR Crore)","IMDb"].copy())

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 7       Hrithik Roshan                       War  2019           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2.reset_index() #indexing properly
# Out:
#     index               Actor                      Film  Year  \
# 0       2          Aamir Khan                    Dangal  2016
# 1      10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 2       1         Salman Khan           Tiger Zinda Hai  2017
# 3       5  Ayushmann Khurrana                 Andhadhun  2018
# 4       6       Rajkummar Rao                     Stree  2018
# 5       4       Ranveer Singh                 Padmaavat  2018
# 6       8        Akshay Kumar                Good Newwz  2019
# 7      11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 8       7      Hrithik Roshan                       War  2019
# 9       9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 10      3       Ranbir Kapoor                Brahmastra  2022
# 11      0      Shah Rukh Khan                   Pathaan  2023
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0         Biography                  2024   8.4
# 1   Romantic Comedy                   201   6.1
# ...

# %%
#now to drop those prev index which is not needed 
df2.reset_index(drop=True)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2          Salman Khan           Tiger Zinda Hai  2017           Action
# 3   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5        Ranveer Singh                 Padmaavat  2018       Historical
# 6         Akshay Kumar                Good Newwz  2019           Comedy
# 7        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 8       Hrithik Roshan                       War  2019           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10       Ranbir Kapoor                Brahmastra  2022          Fantasy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df2 #No change in OG data set
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 7       Hrithik Roshan                       War  2019           Action
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#Now We need that our df has same changes of index that the series came in ascending order as df2
df2.reset_index(drop=True, inplace=True)
print(df)
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
#Ranking giving can be 2 types ascending or descending for descending
#ascending=False should be done.
df["Rank"]=df["IMDb"].rank()#ranking based on BoxOffice(INR Crore) it can be of IMDb too

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
#to remove the average values , new syntax
df["Rank"]=df["IMDb"].rank(method="dense")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
#Renaming Columns & Index
df.rename(columns={"Year":"Saal"}, inplace=True)
df
# Out:
#                  Actor                      Film  Saal            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df2 = df.rename(index={0: "Actor", 1: "Film"}).copy()

df2
# Out:
#                     Actor                      Film  Saal            Genre  \
# Actor      Shah Rukh Khan                   Pathaan  2023           Action
# Film          Salman Khan           Tiger Zinda Hai  2017           Action
# 2              Aamir Khan                    Dangal  2016        Biography
# 3           Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4           Ranveer Singh                 Padmaavat  2018       Historical
# 5      Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6           Rajkummar Rao                     Stree  2018    Horror Comedy
# 7          Hrithik Roshan                       War  2019           Action
# 8            Akshay Kumar                Good Newwz  2019           Comedy
# 9           Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10           Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# ...

# %%
df.rename(index={5: "row1", 6: "row2"}, inplace=True)
print(df)
# Out:
#                    Actor                      Film  Saal            Genre  \
# 0         Shah Rukh Khan                   Pathaan  2023           Action
# 1            Salman Khan           Tiger Zinda Hai  2017           Action
# 2             Aamir Khan                    Dangal  2016        Biography
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# row1  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# row2       Rajkummar Rao                     Stree  2018    Horror Comedy
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
# Step 1: Copy the original DataFrame
df_copy = df.copy()

# Step 2: Rename in the copied DataFrame
df_copy.rename(columns={'Film': 'A', 'IMDb': 'B'}, inplace=True)

df_copy
# Out:
#                    Actor                         A  Saal            Genre  \
# 0         Shah Rukh Khan                   Pathaan  2023           Action
# 1            Salman Khan           Tiger Zinda Hai  2017           Action
# 2             Aamir Khan                    Dangal  2016        Biography
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# row1  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# row2       Rajkummar Rao                     Stree  2018    Horror Comedy
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df
# Out:
#                    Actor                      Film  Saal            Genre  \
# 0         Shah Rukh Khan                   Pathaan  2023           Action
# 1            Salman Khan           Tiger Zinda Hai  2017           Action
# 2             Aamir Khan                    Dangal  2016        Biography
# 3          Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4          Ranveer Singh                 Padmaavat  2018       Historical
# row1  Ayushmann Khurrana                 Andhadhun  2018         Thriller
# row2       Rajkummar Rao                     Stree  2018    Horror Comedy
# 7         Hrithik Roshan                       War  2019           Action
# 8           Akshay Kumar                Good Newwz  2019           Comedy
# 9          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10          Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11         Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df6 = df[["Film", "IMDb", "Saal"]]
df6# Reorder as desired
# Out:
#                           Film  IMDb  Saal
# 0                      Pathaan   7.2  2023
# 1              Tiger Zinda Hai   6.0  2017
# 2                       Dangal   8.4  2016
# 3                   Brahmastra   5.6  2022
# 4                    Padmaavat   7.0  2018
# row1                 Andhadhun   8.3  2018
# row2                     Stree   7.5  2018
# 7                          War   6.5  2019
# 8                   Good Newwz   7.0  2019
# 9            Bhool Bhulaiyaa 2   5.9  2022
# 10       Badrinath Ki Dulhania   6.1  2017
# 11    Uri: The Surgical Strike   8.2  2019

# %%
#You can also move one column to the front:
cols = ["IMDb"] + [col for col in df.columns if col != "IMDb"]
df = df[cols]
df
# Out:
#       IMDb  IMDb               Actor                      Film  Saal  \
# 0      7.2   7.2      Shah Rukh Khan                   Pathaan  2023
# 1      6.0   6.0         Salman Khan           Tiger Zinda Hai  2017
# 2      8.4   8.4          Aamir Khan                    Dangal  2016
# 3      5.6   5.6       Ranbir Kapoor                Brahmastra  2022
# 4      7.0   7.0       Ranveer Singh                 Padmaavat  2018
# row1   8.3   8.3  Ayushmann Khurrana                 Andhadhun  2018
# row2   7.5   7.5       Rajkummar Rao                     Stree  2018
# 7      6.5   6.5      Hrithik Roshan                       War  2019
# 8      7.0   7.0        Akshay Kumar                Good Newwz  2019
# 9      5.9   5.9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 10     6.1   6.1        Varun Dhawan     Badrinath Ki Dulhania  2017
# 11     8.2   8.2       Vicky Kaushal  Uri: The Surgical Strike  2019
#
#                 Genre  BoxOffice(INR Crore)  Rank
# ...
